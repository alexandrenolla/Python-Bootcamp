# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Todos os dias, o nosso sistema atualiza as vendas do dia anterior.
# O seu trabalho diário, como analista, é enviar um e-mail para a diretoria, assim que começar a trabalhar, com o faturamento e a quantidade de produtos vendidos no dia anterior
#
# E-mail da diretoria: seugmail+diretoria@gmail.com<br>
# Local onde o sistema disponibiliza as vendas do dia anterior: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing
#
# Para resolver isso, vamos usar o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado
#
# Referência do pyautogui: https://pyautogui.readthedocs.io/en/latest/quickstart.html

# %%
# !pip install pyautogui
# Out:
# Requirement already satisfied: pyautogui in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.9.53)
# Requirement already satisfied: pymsgbox in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: PyTweening>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyautogui) (1.0.4)
# Requirement already satisfied: pyscreeze>=0.1.21 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyautogui) (0.1.28)
# Requirement already satisfied: pygetwindow>=0.0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyobjc-core in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyautogui) (9.0.1)
# Requirement already satisfied: pyrect in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: rubicon-objc in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mouseinfo->pyautogui) (0.4.3)
# Requirement already satisfied: pyobjc-framework-SpriteKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Social==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Contacts==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Network==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AdServices==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Metal==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NetFS==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreML==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OSLog==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Quartz==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Security==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AVKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-EventKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-WebKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Automator==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Photos==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameController==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Accounts==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PushKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MapKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreData==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CallKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Intents==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Speech==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreText==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-Vision==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-PassKit==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==9.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc->pyautogui) (9.0.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

# pyautogui.click -> clicar
# pyautogui.press -> apertar 1 tecla
# pyautogui.hotkey -> conjunto de teclas
# pyautogui.write -> escreve um texto

# Passo 1: Entrar no sistema da empresa (no nosso caso é o link do drive)
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5)

# Passo 2: Navegar no sistema e encontrar a base de vendas (entrar na pasta exportar)
pyautogui.click(x=1023, y=710, clicks=2)
time.sleep(2)

# Passo 3: Fazer o download da base de vendas
pyautogui.click(x=1100, y=904) # clicar no arquivo
pyautogui.click(x=3288, y=411) # clicar nos 3 pontinhos
pyautogui.click(x=2716, y=1523) # clicar no fazer download
time.sleep(5) # esperar o download acabar

# %% [markdown]
# ### Vamos agora ler o arquivo baixado para pegar os indicadores
#
# - Faturamento
# - Quantidade de Produtos

# %%
# Passo 4: Importar a base de vendas pro Python
import pandas as pd

tabela = pd.read_excel(r"C:\Users\joaol\Downloads\Vendas - Dez.xlsx")
display(tabela)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# 0              5             114          570
# 1              1             269          269
# 2              2             363          726
# 3              1             250          250
# 4              3              92          276
# ...          ...             ...          ...
# 7084           2             102          204
# 7085           4             270         1080
# 7086           1              87           87
# 7087           1             108          108
# 7088           2             133          266
#
# [7089 rows x 7 columns]

# %%
# Passo 5: Calcular os indicadores da empresa
faturamento = tabela["Valor Final"].sum()
print(faturamento)
quantidade = tabela["Quantidade"].sum()
print(quantidade)
# Out:
# 2917311
# 15227

# %% [markdown]
# ### Vamos agora enviar um e-mail pelo gmail

# %%
# Passo 6: Enviar um e-mail para a diretoria com os indicadores de venda

# abrir aba
pyautogui.hotkey("ctrl", "t")

# entrar no link do email - https://mail.google.com/mail/u/0/#inbox
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(5)

# clicar no botão escrever
pyautogui.click(x=240, y=415)

# preencher as informações do e-mail
pyautogui.write("pythonimpressionador@gmail.com")
pyautogui.press("tab") # selecionar o email

pyautogui.press("tab") # pular para o campo de assunto
pyperclip.copy("Relatório de Vendas")
pyautogui.hotkey("ctrl", "v")

pyautogui.press("tab") # pular para o campo de corpo do email

texto = f"""
Prezados,

Segue relatório de vendas.
Faturamento: R${faturamento:,.2f}
Quantidade de produtos vendidos: {quantidade:,}

Qualquer dúvida estou à disposição.
Att.,
Lira do Python
"""

# formatação dos números (moeda, dinheiro)

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

# enviar o e-mail
pyautogui.hotkey("ctrl", "enter")

# %% [markdown]
# #### Use esse código para descobrir qual a posição de um item que queira clicar
#
# - Lembre-se: a posição na sua tela é diferente da posição na minha tela

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1274, y=1182)
